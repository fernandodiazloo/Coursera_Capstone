# %% [markdown]
# # Capstone project
#
# In this project I will analyse top 40 most visited cities.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Get cities data
#
# Read the list of 40 most visited cities and get their coordinates

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="ny_explorer")

r = requests.get("https://www.listchallenges.com/top-100-most-visited-cities-in-the-world")
soup = BeautifulSoup (r.text, "html.parser")

divs = soup.findAll("div", {"class": "item-name"})
cities = []
for div in divs:
    name = div.text.strip() 
    location = geolocator.geocode(name)
    cities.append([name, location])
    
cities[0]
# Out:
# ['Hong Kong, China',
#  Location(香港 Hong Kong, 中西區 Central and Western District, HK, PACIFIC PLACE, 中国, (22.2793278, 114.1628131, 0.0))]

# %% [markdown]
# ## Collect Foursquare data
#
# Get a list of venues around city centers
#
# 0. Prepare credentials
# 1. Read category tree
# 2. Read venues
# 3. Transform venue data from json into dataframe
# 0. Save it for future use

# %%
# Authentication preparation

CLIENT_ID = 'REPLACE WITH YOUR ID OR CREATE A FILE FS_cred.txt' # your Foursquare ID
CLIENT_SECRET = 'REPLACE WITH YOUR SECRET OR CREATE A FILE FS_cred.txt' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
try:
    filename = "FS_cred.txt" 
    # This block will read 
    with open(filename, "r") as f:
        lines = f.readlines()
        CLIENT_ID = lines[0].strip()
        CLIENT_SECRET = lines[1].strip()
        print ("Foursquare credentials read from '{}'".format(filename))
except:
    print ("Could not read '{}'".format(filename))
    
AUTH="client_id={}&client_secret={}&v={}&".format(CLIENT_ID, CLIENT_SECRET, VERSION)

#print('Your credentails:', AUTH)
# Out:
# Foursquare credentials read from 'FS_cred.txt'

# %%
# Reading category trees
categories = dict()

def topParent(me):
    if me["parent"] == None:
        return me
    else:
        return topParent(me["parent"])
    
def traverseCategories(lst, parent=None):
    for i in lst:
        c = dict()
        c["id"]=i["id"]
        c["name"]=i["name"]
        #print(c["id"], c["name"], " " if parent == None else "({})".format(parent["name"]))
        categories[c["id"]] = c
        c["parent"] = parent
        traverseCategories(i["categories"], c)
        
def primaryCategory(venue):
    if len(venue["categories"]) == 0:
        return ""
    return next(filter(lambda x: x["primary"]==True, venue["categories"]))

url = 'https://api.foursquare.com/v2/venues/categories?{}'.format(AUTH)
json_categories = requests.get(url).json()        
traverseCategories(json_categories["response"]["categories"])  

print ("Testing category tree: ")
print ("Must be 'Laser Tag': ", categories["52e81612bcbc57f1066b79e6"]["name"])
print ("Must be 'Arts & Entertainment': ", topParent(categories["4bf58dd8d48988d188941735"])["name"])
# Out:
# Testing category tree:
# Must be 'Laser Tag':  Laser Tag
# Must be 'Arts & Entertainment':  Arts & Entertainment

# %%
# Single Foursquare API call to get list of venues in a rectangular area
# Retuns list of json venues
def fs_api_request_search_rect(lat, lng, dlat, dlng):
    LIMIT = 1000
    url = 'https://api.foursquare.com/v2/venues/search?{}&intent=browse&sw={},{}&ne={},{}&limit={}'.format(
                AUTH, 
                lat, 
                lng, 
                lat+dlat, 
                lng+dlng, 
                LIMIT)
    json = requests.get(url).json()
    if not "venues" in json["response"]:
        print("Request failed, will try once again. See response below")
        print(json)
        json = requests.get(url).json()

    return json["response"]["venues"]

# Scan city for venues by making Foursquare calls about several tiles of the city.
# Making several calls about small tiles of the area brings more results than one call about whole area
def scan_city(center_lat, center_lng):
    jsonAllCityVenues = []
    dlat = 0.005
    dlng = 0.005
    n = 4
    for i in range(n):
        for j in range(n):
            l1 = center_lat+(i-n/2)*dlat
            l2 = center_lng+(j-n/2)*dlng
            jsonVenues = fs_api_request_search_rect(l1, l2, dlat, dlng)
            print("Tile ({},{}): {} venues".format(i, j, len(jsonVenues)), end="\r")
            jsonAllCityVenues = jsonAllCityVenues + jsonVenues
    print()
    return jsonAllCityVenues

# %%
# Parses json tree with venues and adds them to a list (venues_list variable)
def append_venues_list(city, json_venues):
    for json_venue in json_venues:
        cnum = len(json_venue["categories"])
        if cnum > 0:
            category = primaryCategory(json_venue)
            venues_list.append([
                city,
                json_venue["id"],
                json_venue["name"],
                json_venue['location']['lat'],
                json_venue['location']['lng'],
                category["id"],
                category["name"],
                topParent(categories[category["id"]])["name"]
            ]
            )
        else:
            pass
#            print ("Venue '{}' does not have categories. Ignoring".format(json_venue["name"]))

# %%
venues_list=[]
for i in range(0, len(cities)):
    city = cities[i]
    json_venues = scan_city( city[1].latitude, city[1].longitude)
    append_venues_list(city[0], json_venues)
    print ("City: {}; lat,lon: {}, {}; venues: {}".format(city[0], city[1].latitude, city[1].longitude, len(json_venues)))
# Out:
# Tile (3,3): 173 venues
# City: Hong Kong, China; lat,lon: 22.2793278, 114.1628131; venues: 2827
# Tile (3,3): 84 venuess
# City: Singapore; lat,lon: 1.2904753, 103.8520359; venues: 2961
# Tile (3,3): 184 venues
# City: Bangkok, Thailand; lat,lon: 13.7538929, 100.8160803; venues: 2809
# Tile (3,3): 98 venuess
# City: London, United Kingdom; lat,lon: 51.5073219, -0.1276474; venues: 2499
# Tile (3,3): 115 venues
# City: Paris, France; lat,lon: 48.8566101, 2.3514992; venues: 2431
# Tile (3,3): 81 venuess
# City: Macau; lat,lon: 22.1899448, 113.5380454; venues: 2773
# Tile (3,3): 122 venues
# City: New York City, USA; lat,lon: 40.7308619, -73.9871558; venues: 2647
# Tile (3,3): 139 venues
# City: Shenzhen, China; lat,lon: 22.5445697, 114.0545346; venues: 2608
# Tile (3,3): 199 venues
# City: Kuala Lumpur, Malaysia; lat,lon: 3.1516636, 101.6943028; venues: 2514
# Tile (3,3): 73 venuess
# City: Antalya, Turkey; lat,lon: 36.9009641, 30.6954846; venues: 2346
# Tile (3,3): 197 venues
# City: Istanbul, Turkey; lat,lon: 41.0096334, 28.9651646; venues: 2985
# Tile (3,3): 168 venues
# City: Dubai, United Arab Emirates; lat,lon: 25.0750095, 55.1887608818332; venues: 2375
# Tile (3,3): 197 venues
# City: Seoul, South Korea; lat,lon: 37.5666791, 126.9782914; venues: 2824
# Tile (3,3): 161 venues
# City: Rome, Italy; lat,lon: 41.894802, 12.4853384; venues: 2407
# Tile (3,3): 138 venues
# City: Phuket, Thailand; lat,lon: 7.9366015, 98.3529292; venues: 2713
# Tile (3,3): 77 venuess
# City: Guangzhou, China; lat,lon: 23.1301964, 113.2592945; venues: 2350
# Request failed, will try once again. See response below
# {'meta': {'code': 500, 'errorType': 'server_error', 'errorDetail': 'Foursquare servers are experiencing problems. Please retry and check status.foursquare.com for updates.'}, 'response': {}}
# Tile (3,3): 186 venues
# City: Mecca, Saudi Arabia; lat,lon: 21.420847, 39.826869; venues: 2446
# Tile (3,3): 190 venues
# City: Pattaya, Thailand; lat,lon: 12.9318593, 100.9006905; venues: 2425
# Tile (3,3): 199 venues
# City: Taipei, Taiwan; lat,lon: 25.0375198, 121.5636796; venues: 2816
# Tile (3,3): 200 venues
# City: Miami, USA; lat,lon: 25.7742658, -80.1936589; venues: 2433
# Tile (3,3): 198 venues
# City: Prague, Czech Republic; lat,lon: 50.0874654, 14.4212535; venues: 2874
# Tile (3,3): 114 venues
# City: Shanghai, China; lat,lon: 31.2253441, 121.4888922; venues: 2412
# Tile (3,3): 200 venues
# City: Las Vegas, USA; lat,lon: 36.1662859, -115.149225; venues: 2562
# Tile (3,3): 193 venues
# City: Milan, Italy; lat,lon: 45.4667971, 9.1904984; venues: 2487
# Tile (3,3): 197 venues
# City: Barcelona, Spain; lat,lon: 41.3828939, 2.1774322; venues: 2893
# Tile (3,3): 195 venues
# City: Moscow, Russia; lat,lon: 55.7504461, 37.6174943; venues: 2480
# Tile (3,3): 113 venues
# City: Amsterdam, Netherlands; lat,lon: 52.3745403, 4.89797550561798; venues: 2544
# Tile (3,3): 118 venues
# City: Vienna, Austria; lat,lon: 48.2083537, 16.3725042; venues: 2464
# Tile (3,3): 198 venues
# City: Venice, Italy; lat,lon: 45.4371908, 12.3345898; venues: 2665
# Tile (3,3): 199 venues
# City: Los Angeles, USA; lat,lon: 34.0536834, -118.2427669; venues: 2394
# Tile (3,3): 160 venues
# City: Lima, Peru; lat,lon: -12.0621065, -77.0365256; venues: 2238
# Request failed, will try once again. See response below
# {'meta': {'code': 500, 'errorType': 'server_error', 'errorDetail': 'Foursquare servers are experiencing problems. Please retry and check status.foursquare.com for updates.'}, 'response': {}}
# Tile (3,3): 162 venues
# City: Tokyo, Japan; lat,lon: 35.6828387, 139.7594549; venues: 2733
# Tile (3,3): 122 venues
# City: Johannesburg, South Africa; lat,lon: -26.205, 28.049722; venues: 2200
# Tile (3,3): 137 venues
# City: Beijing, China; lat,lon: 39.906217, 116.3912757; venues: 2585
# Tile (3,3): 190 venues
# City: Sofia, Bulgaria; lat,lon: 42.6978634, 23.3221789; venues: 2584
# Tile (3,3): 92 venuess
# City: Orlando, USA; lat,lon: 28.5421097, -81.3790388; venues: 2293
# Tile (3,3): 126 venues
# City: Berlin, Germany; lat,lon: 52.5170365, 13.3888599; venues: 2267
# Tile (3,3): 193 venues
# City: Budapest, Hungary; lat,lon: 47.4983815, 19.0404707; venues: 2690
# Tile (3,3): 196 venues
# City: Ho Chi Minh City, Vietnam; lat,lon: 10.7758439, 106.7017555; venues: 2678
# Tile (3,3): 76 venuess
# City: Florence, Italy; lat,lon: 43.7698712, 11.2555757; venues: 2656

# %%
venues_list = venues_list[:-2461]

# %%
df_venues = pd.DataFrame(venues_list)
df_venues.columns=["city", "id", "name", "lat", "lng", "category_id", "category_name", "top_category"]
df_venues.head()
# Out:
#                city                        id  \
# 0  Hong Kong, China  4ddbc83eb0fb2604df70f99c
# 1  Hong Kong, China  4db74d2c43a10648ae161f3a
# 2  Hong Kong, China  517a2b76e4b06253b7e3fe5d
# 3  Hong Kong, China  517a3f55498ea18ae390a21a
# 4  Hong Kong, China  4d3145f85017a09334e23d9b
#
#                                          name        lat         lng  \
# 0                       22 Barker Road 白加道22號  22.271539  114.156219
# 1                            Mountain View 山景  22.268710  114.152955
# 2        Peak Tram May Road Station (山頂纜車梅道站)  22.273614  114.155979
# 3  Peak Tram Kennedy Road Station (山頂纜車堅尼地道站)  22.276572  114.158045
# 4                           Dynasty Court 帝景園  22.275611  114.152694
#
#                 category_id                             category_name  \
# 0  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 1  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 2  4bf58dd8d48988d1fc931735                        Light Rail Station
# 3  52f2ab2ebcbc57f1066b8b51                              Tram Station
# 4  4f2a210c4b9023bd5841ed28                       Housing Development
#
#          top_category
# 0           Residence
# 1           Residence
# 2  Travel & Transport
# 3  Travel & Transport
# 4           Residence

# %%
df_venues.to_csv("venues_all_40.csv", sep="|", index=False)
df_venues = pd.read_csv("venues_all_40.csv", sep="|")
df_venues.head()
# Out:
#                city                        id  \
# 0  Hong Kong, China  4ddbc83eb0fb2604df70f99c
# 1  Hong Kong, China  4db74d2c43a10648ae161f3a
# 2  Hong Kong, China  517a2b76e4b06253b7e3fe5d
# 3  Hong Kong, China  517a3f55498ea18ae390a21a
# 4  Hong Kong, China  4d3145f85017a09334e23d9b
#
#                                          name        lat         lng  \
# 0                       22 Barker Road 白加道22號  22.271539  114.156219
# 1                            Mountain View 山景  22.268710  114.152955
# 2        Peak Tram May Road Station (山頂纜車梅道站)  22.273614  114.155979
# 3  Peak Tram Kennedy Road Station (山頂纜車堅尼地道站)  22.276572  114.158045
# 4                           Dynasty Court 帝景園  22.275611  114.152694
#
#                 category_id                             category_name  \
# 0  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 1  4d954b06a243a5684965b473  Residential Building (Apartment / Condo)
# 2  4bf58dd8d48988d1fc931735                        Light Rail Station
# 3  52f2ab2ebcbc57f1066b8b51                              Tram Station
# 4  4f2a210c4b9023bd5841ed28                       Housing Development
#
#          top_category
# 0           Residence
# 1           Residence
# 2  Travel & Transport
# 3  Travel & Transport
# 4           Residence

# %% [markdown]
# # Cluster cities by venue categories (top-level)

# %% [markdown]
# **Prepare features of the cities. Calculate ratio of categories, impotant for tourists**

# %%
onehot = pd.get_dummies(df_venues[['top_category']], prefix="", prefix_sep="")
onehot = onehot.drop(["Professional & Other Places", "Residence", "Event", "Travel & Transport"], 1)
onehot['city'] = df_venues['city'] 
fixed_columns = [onehot.columns[-1]] + list(onehot.columns[:-1])
onehot = onehot[fixed_columns]
df_cities = onehot.groupby('city').mean().reset_index()
df_cities.head()
# Out:
#                      city  Arts & Entertainment  College & University  \
# 0  Amsterdam, Netherlands              0.068851              0.014102
# 1         Antalya, Turkey              0.051909              0.012441
# 2       Bangkok, Thailand              0.010443              0.020886
# 3        Barcelona, Spain              0.052873              0.016214
# 4          Beijing, China              0.163474              0.009354
#
#        Food  Nightlife Spot  Outdoors & Recreation  Shop & Service
# 0  0.238490        0.088345               0.063874        0.194525
# 1  0.126984        0.028314               0.066495        0.345774
# 2  0.340852        0.032999               0.061404        0.273601
# 3  0.297497        0.089884               0.076489        0.200564
# 4  0.381292        0.020490               0.068151        0.099332

# %%
#df_cities["Arts & Entertainment"] /= df_cities["Arts & Entertainment"].max()
#df_cities["College & University"] /= df_cities["College & University"].max()
#df_cities["Food"] /= df_cities["Food"].max()
#df_cities["Nightlife Spot"] /= df_cities["Nightlife Spot"].max()
#df_cities["Outdoors & Recreation"] /= df_cities["Outdoors & Recreation"].max()
#df_cities["Shop & Service"] /= df_cities["Shop & Service"].max()
df_cities
# Out:
#                            city  Arts & Entertainment  College & University  \
# 0        Amsterdam, Netherlands              0.068851              0.014102
# 1               Antalya, Turkey              0.051909              0.012441
# 2             Bangkok, Thailand              0.010443              0.020886
# 3              Barcelona, Spain              0.052873              0.016214
# 4                Beijing, China              0.163474              0.009354
# 5               Berlin, Germany              0.059406              0.048605
# 6             Budapest, Hungary              0.070539              0.021501
# 7   Dubai, United Arab Emirates              0.015744              0.022901
# 8               Florence, Italy              0.079353              0.029661
# 9              Guangzhou, China              0.045695              0.010101
# 10    Ho Chi Minh City, Vietnam              0.019283              0.017354
# 11             Hong Kong, China              0.037634              0.009677
# 12             Istanbul, Turkey              0.040230              0.049696
# 13   Johannesburg, South Africa              0.054956              0.033385
# 14       Kuala Lumpur, Malaysia              0.027496              0.109137
# 15               Las Vegas, USA              0.145425              0.006944
# 16                   Lima, Peru              0.051494              0.070345
# 17       London, United Kingdom              0.087485              0.008910
# 18             Los Angeles, USA              0.097408              0.006256
# 19                        Macau              0.053625              0.009819
# 20          Mecca, Saudi Arabia              0.010685              0.003400
# 21                   Miami, USA              0.067190              0.020942
# 22                 Milan, Italy              0.054515              0.021640
# 23               Moscow, Russia              0.088510              0.054405
# 24           New York City, USA              0.050598              0.055378
# 25                 Orlando, USA              0.081586              0.019143
# 26                Paris, France              0.068574              0.038284
# 27            Pattaya, Thailand              0.022181              0.006470
# 28             Phuket, Thailand              0.031546              0.091877
# 29       Prague, Czech Republic              0.089279              0.071353
# 30                  Rome, Italy              0.096555              0.025521
# 31           Seoul, South Korea              0.037023              0.005924
# 32              Shanghai, China              0.030174              0.007544
# 33              Shenzhen, China              0.031804              0.006441
# 34                    Singapore              0.060376              0.020607
# 35              Sofia, Bulgaria              0.056648              0.026357
# 36               Taipei, Taiwan              0.026760              0.004399
# 37                 Tokyo, Japan              0.104412              0.006618
# 38                Venice, Italy              0.089101              0.016826
# 39              Vienna, Austria              0.091558              0.044099
#
#         Food  Nightlife Spot  Outdoors & Recreation  Shop & Service
# 0   0.238490        0.088345               0.063874        0.194525
# 1   0.126984        0.028314               0.066495        0.345774
# 2   0.340852        0.032999               0.061404        0.273601
# 3   0.297497        0.089884               0.076489        0.200564
# 4   0.381292        0.020490               0.068151        0.099332
# 5   0.172367        0.039604               0.032403        0.225473
# 6   0.158431        0.061486               0.107507        0.174651
# 7   0.214218        0.031966               0.186069        0.240935
# 8   0.340524        0.072419               0.070108        0.179507
# 9   0.521886        0.013949               0.029822        0.149591
# 10  0.429233        0.075202               0.038180        0.166988
# 11  0.298925        0.061290               0.052688        0.229391
# 12  0.188303        0.020284               0.052400        0.372211
# 13  0.198767        0.056497               0.043657        0.236775
# 14  0.238156        0.018613               0.045685        0.151438
# 15  0.152778        0.073121               0.057190        0.295752
# 16  0.202299        0.028966               0.057931        0.224828
# 17  0.213852        0.085865               0.056298        0.192386
# 18  0.249777        0.042895               0.075514        0.206881
# 19  0.507553        0.030211               0.057779        0.126511
# 20  0.169014        0.004371               0.042254        0.128218
# 21  0.182373        0.041449               0.095113        0.165358
# 22  0.171452        0.037869               0.047441        0.332501
# 23  0.127487        0.023143               0.047097        0.284206
# 24  0.170120        0.060159               0.059363        0.259363
# 25  0.130811        0.099362               0.089335        0.107566
# 26  0.243164        0.058898               0.044594        0.321414
# 27  0.340111        0.061922               0.034196        0.275416
# 28  0.246451        0.040221               0.120662        0.192429
# 29  0.170826        0.069596               0.079438        0.253779
# 30  0.274351        0.057422               0.073160        0.135262
# 31  0.507590        0.037023               0.036283        0.158460
# 32  0.446959        0.037247               0.047148        0.192834
# 33  0.479871        0.041465               0.040258        0.134058
# 34  0.320680        0.071945               0.053868        0.217281
# 35  0.187648        0.059795               0.033438        0.311959
# 36  0.541056        0.023094               0.038123        0.186217
# 37  0.295221        0.038235               0.091544        0.158456
# 38  0.270746        0.054302               0.130784        0.132696
# 39  0.183956        0.070979               0.058799        0.212096

# %% [markdown]
# **Do cluster and assign labels to cities**

# %%
from sklearn.cluster import KMeans
kclusters = 5
city_clustering = df_cities.drop("city", 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(city_clustering)
df_cities["Class"] = kmeans.labels_
df_cities.head()
# Out:
#                      city  Arts & Entertainment  College & University  \
# 0  Amsterdam, Netherlands              0.068851              0.014102
# 1         Antalya, Turkey              0.051909              0.012441
# 2       Bangkok, Thailand              0.010443              0.020886
# 3        Barcelona, Spain              0.052873              0.016214
# 4          Beijing, China              0.163474              0.009354
#
#        Food  Nightlife Spot  Outdoors & Recreation  Shop & Service  Class
# 0  0.238490        0.088345               0.063874        0.194525      3
# 1  0.126984        0.028314               0.066495        0.345774      0
# 2  0.340852        0.032999               0.061404        0.273601      4
# 3  0.297497        0.089884               0.076489        0.200564      4
# 4  0.381292        0.020490               0.068151        0.099332      2

# %% [markdown]
# **Now lets see what clusters are and how we can interpret them**

# %%
centers = pd.DataFrame(kmeans.cluster_centers_)
centers.columns = city_clustering.columns
centers["# of cities"] = df_cities.groupby("Class").count()["city"]
centers
# Out:
#    Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 0              0.071743              0.037389  0.170973        0.047909
# 1              0.034909              0.008797  0.490592        0.036885
# 2              0.106579              0.017596  0.312427        0.048574
# 3              0.058282              0.036757  0.199926        0.050758
# 4              0.036701              0.014771  0.319613        0.063608
#
#    Outdoors & Recreation  Shop & Service  # of cities
# 0               0.054162        0.308551            9
# 1               0.041085        0.159237            7
# 2               0.086750        0.141050            5
# 3               0.076793        0.189540           14
# 4               0.055729        0.239250            5

# %%
df_cities
# Out:
#                            city  Arts & Entertainment  College & University  \
# 0        Amsterdam, Netherlands              0.068851              0.014102
# 1               Antalya, Turkey              0.051909              0.012441
# 2             Bangkok, Thailand              0.010443              0.020886
# 3              Barcelona, Spain              0.052873              0.016214
# 4                Beijing, China              0.163474              0.009354
# 5               Berlin, Germany              0.059406              0.048605
# 6             Budapest, Hungary              0.070539              0.021501
# 7   Dubai, United Arab Emirates              0.015744              0.022901
# 8               Florence, Italy              0.079353              0.029661
# 9              Guangzhou, China              0.045695              0.010101
# 10    Ho Chi Minh City, Vietnam              0.019283              0.017354
# 11             Hong Kong, China              0.037634              0.009677
# 12             Istanbul, Turkey              0.040230              0.049696
# 13   Johannesburg, South Africa              0.054956              0.033385
# 14       Kuala Lumpur, Malaysia              0.027496              0.109137
# 15               Las Vegas, USA              0.145425              0.006944
# 16                   Lima, Peru              0.051494              0.070345
# 17       London, United Kingdom              0.087485              0.008910
# 18             Los Angeles, USA              0.097408              0.006256
# 19                        Macau              0.053625              0.009819
# 20          Mecca, Saudi Arabia              0.010685              0.003400
# 21                   Miami, USA              0.067190              0.020942
# 22                 Milan, Italy              0.054515              0.021640
# 23               Moscow, Russia              0.088510              0.054405
# 24           New York City, USA              0.050598              0.055378
# 25                 Orlando, USA              0.081586              0.019143
# 26                Paris, France              0.068574              0.038284
# 27            Pattaya, Thailand              0.022181              0.006470
# 28             Phuket, Thailand              0.031546              0.091877
# 29       Prague, Czech Republic              0.089279              0.071353
# 30                  Rome, Italy              0.096555              0.025521
# 31           Seoul, South Korea              0.037023              0.005924
# 32              Shanghai, China              0.030174              0.007544
# 33              Shenzhen, China              0.031804              0.006441
# 34                    Singapore              0.060376              0.020607
# 35              Sofia, Bulgaria              0.056648              0.026357
# 36               Taipei, Taiwan              0.026760              0.004399
# 37                 Tokyo, Japan              0.104412              0.006618
# 38                Venice, Italy              0.089101              0.016826
# 39              Vienna, Austria              0.091558              0.044099
#
#         Food  Nightlife Spot  Outdoors & Recreation  Shop & Service  Class
# 0   0.238490        0.088345               0.063874        0.194525      3
# 1   0.126984        0.028314               0.066495        0.345774      0
# 2   0.340852        0.032999               0.061404        0.273601      4
# 3   0.297497        0.089884               0.076489        0.200564      4
# 4   0.381292        0.020490               0.068151        0.099332      2
# 5   0.172367        0.039604               0.032403        0.225473      3
# 6   0.158431        0.061486               0.107507        0.174651      3
# 7   0.214218        0.031966               0.186069        0.240935      3
# 8   0.340524        0.072419               0.070108        0.179507      2
# 9   0.521886        0.013949               0.029822        0.149591      1
# 10  0.429233        0.075202               0.038180        0.166988      1
# 11  0.298925        0.061290               0.052688        0.229391      4
# 12  0.188303        0.020284               0.052400        0.372211      0
# 13  0.198767        0.056497               0.043657        0.236775      3
# 14  0.238156        0.018613               0.045685        0.151438      3
# 15  0.152778        0.073121               0.057190        0.295752      0
# 16  0.202299        0.028966               0.057931        0.224828      3
# 17  0.213852        0.085865               0.056298        0.192386      3
# 18  0.249777        0.042895               0.075514        0.206881      3
# 19  0.507553        0.030211               0.057779        0.126511      1
# 20  0.169014        0.004371               0.042254        0.128218      3
# 21  0.182373        0.041449               0.095113        0.165358      3
# 22  0.171452        0.037869               0.047441        0.332501      0
# 23  0.127487        0.023143               0.047097        0.284206      0
# 24  0.170120        0.060159               0.059363        0.259363      0
# 25  0.130811        0.099362               0.089335        0.107566      3
# 26  0.243164        0.058898               0.044594        0.321414      0
# 27  0.340111        0.061922               0.034196        0.275416      4
# 28  0.246451        0.040221               0.120662        0.192429      3
# 29  0.170826        0.069596               0.079438        0.253779      0
# 30  0.274351        0.057422               0.073160        0.135262      2
# 31  0.507590        0.037023               0.036283        0.158460      1
# 32  0.446959        0.037247               0.047148        0.192834      1
# 33  0.479871        0.041465               0.040258        0.134058      1
# 34  0.320680        0.071945               0.053868        0.217281      4
# 35  0.187648        0.059795               0.033438        0.311959      0
# 36  0.541056        0.023094               0.038123        0.186217      1
# 37  0.295221        0.038235               0.091544        0.158456      2
# 38  0.270746        0.054302               0.130784        0.132696      2
# 39  0.183956        0.070979               0.058799        0.212096      3

# %% [markdown]
# **Assign label to cluster _based on particular numbers we see_**

# %%
class_names = {
    centers["Food"                ].idxmax(): "Eat",
    centers["Nightlife Spot"      ].idxmax(): "Dance",
    centers["# of cities"         ].idxmax(): "Balanced",
    centers["Shop & Service"      ].idxmax(): "Shop",
    centers["Arts & Entertainment"].idxmax(): "Look"
}
centers["Label"] = centers.index.map(lambda x: class_names[x])
centers
# Out:
#    Arts & Entertainment  College & University      Food  Nightlife Spot  \
# 0              0.071743              0.037389  0.170973        0.047909
# 1              0.034909              0.008797  0.490592        0.036885
# 2              0.106579              0.017596  0.312427        0.048574
# 3              0.058282              0.036757  0.199926        0.050758
# 4              0.036701              0.014771  0.319613        0.063608
#
#    Outdoors & Recreation  Shop & Service  # of cities     Label
# 0               0.054162        0.308551            9      Shop
# 1               0.041085        0.159237            7       Eat
# 2               0.086750        0.141050            5      Look
# 3               0.076793        0.189540           14  Balanced
# 4               0.055729        0.239250            5     Dance

# %% [markdown]
# **Here is our classification**

# %%
df_cities["Class"] = df_cities["Class"].map(lambda x: class_names[x])
df_cities
# Out:
#                            city  Arts & Entertainment  College & University  \
# 0        Amsterdam, Netherlands              0.068851              0.014102
# 1               Antalya, Turkey              0.051909              0.012441
# 2             Bangkok, Thailand              0.010443              0.020886
# 3              Barcelona, Spain              0.052873              0.016214
# 4                Beijing, China              0.163474              0.009354
# 5               Berlin, Germany              0.059406              0.048605
# 6             Budapest, Hungary              0.070539              0.021501
# 7   Dubai, United Arab Emirates              0.015744              0.022901
# 8               Florence, Italy              0.079353              0.029661
# 9              Guangzhou, China              0.045695              0.010101
# 10    Ho Chi Minh City, Vietnam              0.019283              0.017354
# 11             Hong Kong, China              0.037634              0.009677
# 12             Istanbul, Turkey              0.040230              0.049696
# 13   Johannesburg, South Africa              0.054956              0.033385
# 14       Kuala Lumpur, Malaysia              0.027496              0.109137
# 15               Las Vegas, USA              0.145425              0.006944
# 16                   Lima, Peru              0.051494              0.070345
# 17       London, United Kingdom              0.087485              0.008910
# 18             Los Angeles, USA              0.097408              0.006256
# 19                        Macau              0.053625              0.009819
# 20          Mecca, Saudi Arabia              0.010685              0.003400
# 21                   Miami, USA              0.067190              0.020942
# 22                 Milan, Italy              0.054515              0.021640
# 23               Moscow, Russia              0.088510              0.054405
# 24           New York City, USA              0.050598              0.055378
# 25                 Orlando, USA              0.081586              0.019143
# 26                Paris, France              0.068574              0.038284
# 27            Pattaya, Thailand              0.022181              0.006470
# 28             Phuket, Thailand              0.031546              0.091877
# 29       Prague, Czech Republic              0.089279              0.071353
# 30                  Rome, Italy              0.096555              0.025521
# 31           Seoul, South Korea              0.037023              0.005924
# 32              Shanghai, China              0.030174              0.007544
# 33              Shenzhen, China              0.031804              0.006441
# 34                    Singapore              0.060376              0.020607
# 35              Sofia, Bulgaria              0.056648              0.026357
# 36               Taipei, Taiwan              0.026760              0.004399
# 37                 Tokyo, Japan              0.104412              0.006618
# 38                Venice, Italy              0.089101              0.016826
# 39              Vienna, Austria              0.091558              0.044099
#
#         Food  Nightlife Spot  Outdoors & Recreation  Shop & Service     Class
# 0   0.238490        0.088345               0.063874        0.194525  Balanced
# 1   0.126984        0.028314               0.066495        0.345774      Shop
# 2   0.340852        0.032999               0.061404        0.273601     Dance
# 3   0.297497        0.089884               0.076489        0.200564     Dance
# 4   0.381292        0.020490               0.068151        0.099332      Look
# 5   0.172367        0.039604               0.032403        0.225473  Balanced
# 6   0.158431        0.061486               0.107507        0.174651  Balanced
# 7   0.214218        0.031966               0.186069        0.240935  Balanced
# 8   0.340524        0.072419               0.070108        0.179507      Look
# 9   0.521886        0.013949               0.029822        0.149591       Eat
# 10  0.429233        0.075202               0.038180        0.166988       Eat
# 11  0.298925        0.061290               0.052688        0.229391     Dance
# 12  0.188303        0.020284               0.052400        0.372211      Shop
# 13  0.198767        0.056497               0.043657        0.236775  Balanced
# 14  0.238156        0.018613               0.045685        0.151438  Balanced
# 15  0.152778        0.073121               0.057190        0.295752      Shop
# 16  0.202299        0.028966               0.057931        0.224828  Balanced
# 17  0.213852        0.085865               0.056298        0.192386  Balanced
# 18  0.249777        0.042895               0.075514        0.206881  Balanced
# 19  0.507553        0.030211               0.057779        0.126511       Eat
# 20  0.169014        0.004371               0.042254        0.128218  Balanced
# 21  0.182373        0.041449               0.095113        0.165358  Balanced
# 22  0.171452        0.037869               0.047441        0.332501      Shop
# 23  0.127487        0.023143               0.047097        0.284206      Shop
# 24  0.170120        0.060159               0.059363        0.259363      Shop
# 25  0.130811        0.099362               0.089335        0.107566  Balanced
# 26  0.243164        0.058898               0.044594        0.321414      Shop
# 27  0.340111        0.061922               0.034196        0.275416     Dance
# 28  0.246451        0.040221               0.120662        0.192429  Balanced
# 29  0.170826        0.069596               0.079438        0.253779      Shop
# 30  0.274351        0.057422               0.073160        0.135262      Look
# 31  0.507590        0.037023               0.036283        0.158460       Eat
# 32  0.446959        0.037247               0.047148        0.192834       Eat
# 33  0.479871        0.041465               0.040258        0.134058       Eat
# 34  0.320680        0.071945               0.053868        0.217281     Dance
# 35  0.187648        0.059795               0.033438        0.311959      Shop
# 36  0.541056        0.023094               0.038123        0.186217       Eat
# 37  0.295221        0.038235               0.091544        0.158456      Look
# 38  0.270746        0.054302               0.130784        0.132696      Look
# 39  0.183956        0.070979               0.058799        0.212096  Balanced

# %%
df_hist["Class5"] = df_cities["Class"]
df_hist.to_csv("hist.csv", sep="|", index=False)
df_hist = pd.read_csv("hist.csv", sep="|")
df_hist
# Out:
#                            city  Class    Class1    Class2    Class3  \
# 0        Amsterdam, Netherlands  Dance  Balanced     Dance     Dance
# 1               Antalya, Turkey   Shop      Shop      Shop      Shop
# 2             Bangkok, Thailand   Shop  Balanced  Balanced  Balanced
# 3              Barcelona, Spain   Shop  Balanced  Balanced  Balanced
# 4                Beijing, China   Look      Look      Look      Look
# 5               Berlin, Germany   Shop      Shop      Shop      Shop
# 6             Budapest, Hungary   Look      Look      Look      Look
# 7   Dubai, United Arab Emirates   Shop      Shop      Shop      Shop
# 8               Florence, Italy    Eat  Balanced  Balanced  Balanced
# 9              Guangzhou, China    Eat       Eat       Eat       Eat
# 10    Ho Chi Minh City, Vietnam    Eat  Balanced       Eat       Eat
# 11             Hong Kong, China   Look  Balanced  Balanced  Balanced
# 12             Istanbul, Turkey   Shop      Shop      Shop      Shop
# 13   Johannesburg, South Africa   Shop      Shop      Shop      Shop
# 14       Kuala Lumpur, Malaysia   Look      Look      Look      Look
# 15               Las Vegas, USA   Look      Look      Look      Look
# 16                   Lima, Peru    Eat       Eat  Balanced  Balanced
# 17       London, United Kingdom   Look      Look      Look      Look
# 18             Los Angeles, USA   Look      Look      Look      Look
# 19                        Macau    Eat       Eat       Eat       Eat
# 20          Mecca, Saudi Arabia    Eat  Balanced       Eat       Eat
# 21                   Miami, USA    Eat  Balanced  Balanced  Balanced
# 22                 Milan, Italy   Shop  Balanced  Balanced  Balanced
# 23               Moscow, Russia   Look      Look      Look      Look
# 24           New York City, USA   Look  Balanced  Balanced  Balanced
# 25                 Orlando, USA  Dance      Look     Dance     Dance
# 26                Paris, France   Shop      Shop      Shop      Shop
# 27            Pattaya, Thailand    Eat  Balanced       Eat       Eat
# 28             Phuket, Thailand   Look  Balanced  Balanced  Balanced
# 29       Prague, Czech Republic   Look      Look  Balanced  Balanced
# 30                  Rome, Italy   Look      Look      Look      Look
# 31           Seoul, South Korea    Eat       Eat       Eat       Eat
# 32              Shanghai, China    Eat       Eat       Eat       Eat
# 33              Shenzhen, China   Look  Balanced  Balanced  Balanced
# 34                    Singapore   Shop      Shop      Shop      Shop
# 35              Sofia, Bulgaria   Shop      Shop      Shop      Shop
# 36               Taipei, Taiwan    Eat  Balanced  Balanced  Balanced
# 37                 Tokyo, Japan   Look      Look  Balanced  Balanced
# 38                Venice, Italy   Look      Look      Look      Look
# 39              Vienna, Austria   Shop      Shop      Shop      Shop
#
#       Class4    Class5
# 0       Look  Balanced
# 1       Look      Shop
# 2   Balanced     Dance
# 3      Dance     Dance
# 4        Eat      Look
# 5   Balanced  Balanced
# 6       Shop  Balanced
# 7       Look  Balanced
# 8       Look      Look
# 9        Eat       Eat
# 10       Eat       Eat
# 11  Balanced     Dance
# 12     Dance      Shop
# 13      Shop  Balanced
# 14  Balanced  Balanced
# 15      Shop      Shop
# 16  Balanced  Balanced
# 17  Balanced  Balanced
# 18      Look  Balanced
# 19       Eat       Eat
# 20  Balanced  Balanced
# 21      Look  Balanced
# 22  Balanced      Shop
# 23      Shop      Shop
# 24      Look      Shop
# 25      Shop  Balanced
# 26  Balanced      Shop
# 27     Dance     Dance
# 28  Balanced  Balanced
# 29      Shop      Shop
# 30  Balanced      Look
# 31       Eat       Eat
# 32       Eat       Eat
# 33       Eat       Eat
# 34     Dance     Dance
# 35      Shop      Shop
# 36       Eat       Eat
# 37  Balanced      Look
# 38     Dance      Look
# 39      Look  Balanced

# %%
df_cities.to_csv("cities4.csv", sep="|", index=False)

# %%
for class_name in class_names.values():
    print(class_name)
    print(", ".join(df_cities[df_cities.Class == class_name].city.values))
# Out:
# Eat
# Guangzhou, China, Ho Chi Minh City, Vietnam, Macau, Seoul, South Korea, Shanghai, China, Shenzhen, China, Taipei, Taiwan
# Dance
# Bangkok, Thailand, Barcelona, Spain, Hong Kong, China, Pattaya, Thailand, Singapore
# Balanced
# Amsterdam, Netherlands, Berlin, Germany, Budapest, Hungary, Dubai, United Arab Emirates, Johannesburg, South Africa, Kuala Lumpur, Malaysia, Lima, Peru, London, United Kingdom, Los Angeles, USA, Mecca, Saudi Arabia, Miami, USA, Orlando, USA, Phuket, Thailand, Vienna, Austria
# Shop
# Antalya, Turkey, Istanbul, Turkey, Las Vegas, USA, Milan, Italy, Moscow, Russia, New York City, USA, Paris, France, Prague, Czech Republic, Sofia, Bulgaria
# Look
# Beijing, China, Florence, Italy, Rome, Italy, Tokyo, Japan, Venice, Italy

# %%
print('1')
# Out:
# 1

# %% [markdown]
# # Find "concentration points" for food/entertainment/etc venues

# %%
def find_centers(city, category, df_venues):
    df_to_cluster = df_venues[(df_venues.city == city) & (df_venues.top_category == category)][["lat", "lng"]]
#     print ("Finding clusters for '{}'. {} venues".format(category, len(df_to_cluster)))
    kmeans = KMeans(len(df_to_cluster) // 5, random_state=0).fit(df_to_cluster)
    df_to_cluster["Class"]=kmeans.labels_

    df_clusters = pd.DataFrame(kmeans.cluster_centers_)
    df_clusters.columns = ["lat", "lng"]
    df_clusters["Cnt"] = df_to_cluster.groupby("Class").count()["lat"]
    df_clusters = df_clusters[df_clusters.Cnt >= 5].copy()
    df_clusters.sort_values("Cnt", ascending=False, inplace=True)
    return df_clusters.head(3)

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
# set color scheme for the clusters
cs = ["Arts & Entertainment", "Food", "Shop & Service", "Nightlife Spot"]
k = len(cs)
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
city_number = 25
city_name = cities[city_number][0]
city_location = cities[city_number][1]
category = "Shop & Service"
df_centers = find_centers(cities[city_number][0], category, df_venues)

# %%
city_map = folium.Map(location=[city_location.latitude, city_location.longitude], zoom_start=14)
for i in range(len(cs)):
    category = cs[i]
    color = rainbow[i]
#     print (category, color)
    df_centers = find_centers(cities[city_number][0], category, df_venues)
    for idx in df_centers.index:
        lat = df_centers.lat[idx]
        lng = df_centers.lng[idx]
        cnt = df_centers.Cnt[idx]
        label = '{} - {} venues'.format(category, cnt, lat, lng)
        folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=8,
            popup=label,
            color='black',
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            parse_html=False).add_to(city_map) 

city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors



df_to_cluster = df_venues[(df_venues.city == city_name) & (df_venues.top_category == "Food")][["lat", "lng"]]
kmeans = KMeans(len(df_to_cluster) // 5, random_state=0).fit(df_to_cluster)
df_to_cluster["Class"]=kmeans.labels_

# set color scheme for the clusters
k = df_to_cluster.Class.max() + 1
x = np.arange(3)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

    
city_map = folium.Map(location=[city_location.latitude, city_location.longitude], zoom_start=12)
for idx in df_to_cluster.index:
    lat = df_to_cluster.lat[idx]
    lng = df_to_cluster.lng[idx]
    cls = df_to_cluster.Class[idx]
    label = '{} - {} venues'.format(category, cls)
    
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cls],
        fill=True,
        fill_color=rainbow[cls],
        fill_opacity=0.7,
        parse_html=False).add_to(city_map)  
    
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_to_cluster = df_venues[(df_venues.city == city_name) & (df_venues.top_category == "Food")][["lat", "lng"]]
len(df_to_cluster)
# Out:
# 200

# %% [markdown]
# 0. Посчитать дельту широты и долготы на один километр
# 0. Задавать координаты квадратом
# 0. Сканировать несколько квадратов для одного города
# 0. Сохранять результаты в csv и читать их оттуда
# 0. Список интересных городов и их координат
# 0. Кластеризовать отдельные категории в одном городе и изобразить центры кластеров
# 0. One-hot encoding для категорий точек
# 0. кластеризовать города
